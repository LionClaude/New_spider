# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from utils import write_params

system_name = 'spider3d'
data_dir = '../data/' + system_name + '/'

# %%
names_list = ['spider3d']
if system_name not in names_list:
    print('Warning: invalid system name')

# %%
params = dict()

# TIME
params['int_steps'] = 0.001 # sec
params['series_time'] = 0.1 # sec
params['ep_length'] = 200 # sec
params['therm_length'] = 10 # sec

if system_name == 'spider3d':
    params['wind_type'] = 'bump'

# %%
params['init_xspider'] = 0.0
params['init_yspider'] = 0.0
params['init_zspider'] = 2.0

# %%
params['n_episodes'] = 10

# %%
write_params(params, data_dir, "param_env.txt")
